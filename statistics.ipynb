# %%
import csv 
import numpy as np
import matplotlib.pyplot as plt
import statistics
import pandas as pd

# %%
data_file = open("county_gdp.csv", 'rU')
# Out:
# <ipython-input-92-48ee704e346d>:1: DeprecationWarning: 'U' mode is deprecated
#   data_file = open("county_gdp.csv", 'rU')

# %%
total = []

with open('county_income.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        try:
        total.append(int(row['personal_income']))
total
# Out:
#   File "<ipython-input-111-069018fc17f6>", line 7
#     total.append(int(row['personal_income']))
#     ^
# IndentationError: expected an indented block

# %%
total = []
#name the column called "Total" in my csv as "total" for the number of complaints. 

with open('county_income.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        try:
            total.append(int(row['personal_income']))
        except Exception:
            pass
total
#read the csv file of illegal parking complaints and name it as list_of_numbers.
# Out:
# [41618,
#  45596,
#  35199,
#  30254,
#  34976,
#  28797,
#  36450,
#  37120,
#  33859,
#  35505,
#  34798,
#  39280,
#  36361,
#  33530,
#  36159,
#  43094,
#  38378,
#  32656,
#  31328,
#  35651,
#  36645,
#  39607,
#  36613,
#  36026,
#  31916,
#  42269,
#  32996,
#  36918,
#  34966,
#  34318,
#  35192,
#  32359,
#  36585,
#  40360,
#  42398,
#  36567,
#  54730,
#  33496,
#  37151,
#  34125,
#  38036,
#  42546,
#  38991,
#  32919,
#  51445,
#  39801,
#  33264,
#  36044,
#  38243,
#  33456,
#  43688,
#  39991,
#  30535,
#  32551,
#  37359,
#  32411,
#  33104,
#  38569,
#  54369,
#  31664,
#  34718,
#  40696,
#  38822,
#  40197,
#  36323,
#  32215,
#  35430,
#  56676,
#  54385,
#  66510,
#  43500,
#  143575,
#  82919,
#  59621,
#  56606,
#  67059,
#  61752,
#  68145,
#  52015,
#  67602,
#  63938,
#  30099,
#  65414,
#  45897,
#  51378,
#  83489,
#  47854,
#  69995,
#  43707,
#  71972,
#  81471,
#  49398,
#  62307,
#  47658,
#  58937,
#  59010,
#  34355,
#  40308,
#  48129,
# ...

# %%
my_hist = plt.hist(total, histtype='bar', color=['red'])

plt.show()

# %%
N_points = df['gdp']
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ef6ac5f11b73> in <module>
#       3
#       4 # Generate a normal distribution, center at x=0 and y=5
# ----> 5 x = np.random.randn(N_points)
#       6 y = .4 * x + np.random.randn(100000) + 5
#       7
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randn()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.standard_normal()
#
# common.pyx in numpy.random.common.cont()
#
# TypeError: 'Series' object cannot be interpreted as an integer
